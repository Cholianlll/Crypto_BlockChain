# %%
from web3 import Web3, EthereumTesterProvider
w3 = Web3(Web3.HTTPProvider('https://mainnet.infura.io/v3/2d4d6a59129f49699bc30bab6d81321a'))
w3.isConnected()
w3.eth.get_block('latest')
# Out:
# AttributeDict({'baseFeePerGas': 41113451948,
#  'difficulty': 13326209624895211,
#  'extraData': HexBytes('0x6575726f70652d6e6f727468312d36'),
#  'gasLimit': 30000000,
#  'gasUsed': 16463222,
#  'hash': HexBytes('0xa5b0acfad057dff7ea1519ebf0e98555d1d03bd6b859c7b96c9a83c673874807'),
#  'logsBloom': HexBytes('...'),
#  'miner': '0xEA674fdDe714fd979de3EdF0F56AA9716B898ec8',
#  'mixHash': HexBytes('0x13b0c29d49790b7cbbd896bc96e6366264997a7d2ac2e8b14b79048343d302bd'),
#  'nonce': HexBytes('0xc8eea0696f1a69c7'),
#  'number': 14578741,
#  'parentHash': HexBytes('0x3fcb51577f763f9c8e78a54caecb4cdf1951a5c174694c10893d2620ce2222ba'),
#  'receiptsRoot': HexBytes('0xd7d3c8efecabe8bf861004df6f7859108e655d8d6f53b833b7fe4a7c303a62de'),
#  'sha3Uncles': HexBytes('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'),
#  'size': 93952,
#  'stateRoot': HexBytes('0xbe3c95905cfbb003de2c1ece7505b5c723f0fc4188c4df0eb86c61cbb1f80a58'),
#  'timestamp': 1649874381,
# ...

# %%
import uniswap
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/4g/jz_j1_cd25v2bv9plmhlqqw80000gn/T/ipykernel_35509/1228833766.py in <module>
# ----> 1 import uniswap
#
# ~/Library/CloudStorage/OneDrive-Personal/A_My ToolBox/BlockChain/Uniswap/uniswap.py in <module>
# ----> 1 from uniswap import Uniswap
#       2
#       3 address = None  #"YOUR ADDRESS"          # or None if you're not going to make transactions
#       4 private_key =  None #"YOUR PRIVATE KEY"  # or None if you're not going to make transactions
#       5 version = 2                       # specify which version of Uniswap to use
#
# ImportError: cannot import name 'Uniswap' from partially initialized module 'uniswap' (most likely due to a circular import) (/Users/cholian/Library/CloudStorage/OneDrive-Personal/A_My ToolBox/BlockChain/Uniswap/uniswap.py)

# %%
from uniswap import Uniswap

address = None  #"YOUR ADDRESS"          # or None if you're not going to make transactions
private_key =  None #"YOUR PRIVATE KEY"  # or None if you're not going to make transactions
version = 2                       # specify which version of Uniswap to use
provider = "https://mainnet.infura.io/v3/2d4d6a59129f49699bc30bab6d81321a"    # can also be set through the environment variable `PROVIDER`
uniswap = Uniswap(address=address, private_key=private_key, version=version, provider=provider)

# Some token addresses we'll be using later in this guide
eth = "0x0000000000000000000000000000000000000000"
bat = "0x0D8775F648430679A709E98d2b0Cb6250d2887EF"
dai = "0x6B175474E89094C44Da98b954EedeAC495271d0F"

uniswap.get_price_input(eth, dai, 10**18)
# Out:
# 3073335451265329159813

# %%
uniswap.get_price_output(eth, dai, 1_000 * 10**18)
# Out:
# 325292019308794862
